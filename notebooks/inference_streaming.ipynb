# %%
import os
import json
import joblib
import pandas as pd
from notebook_helper import setup_repo_path
setup_repo_path()
from matching.loaders.load_attempts import load_attempts, filter_dataframe_by_columns
from matching.loaders.load_voterfile import load_voterfile_chunk
from matching.candidates.block_candidates import block_candidate_pairs
from matching.features.feature_builder import add_features
from matching.modeling.predict import predict_chunk
from matching.gold.gold_pairs import add_normalized_keys

PROGRESS_FILE = "progress.json"

def load_progress():
    if os.path.exists(PROGRESS_FILE):
        with open(PROGRESS_FILE, "r") as f:
            return json.load(f)
    else:
        return {}

def save_progress(progress):
    with open(PROGRESS_FILE, "w") as f:
        json.dump(progress, f)

def save_chunk_results(candidates_df, chunk_idx, output_dir="/Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype"):
    os.makedirs(output_dir, exist_ok=True)
    filename = os.path.join(output_dir, f"predicted_matches_chunk_{chunk_idx}.csv")
    candidates_df.to_csv(filename, index=False)
    print(f"Chunk {chunk_idx}: Saved {len(candidates_df)} rows to {filename}")

def stream_inference(attempts_path, db_engine, sql, model_path, chunksize=5000):
    # Load full attempts dataframe first
    attempts = load_attempts(attempts_path)

    # Rename columns consistently
    attempts = attempts.rename(columns={
        "first_name": "first_name_att",
        "last_name": "last_name_att",
        "date_of_birth": "dob_raw_att",
        "voting_zipcode": "zip_raw_att",
    })

    # Apply required columns filter
    required_columns = ["first_name_att", "last_name_att"]
    attempts = filter_dataframe_by_columns(attempts, required_columns)
    print(f"Attempts after required columns filter: {len(attempts)}")

    # Apply upload_time filter
    attempts = attempts[attempts["upload_time"].astype(str).str.contains("2024", na=False)]
    print(f"Attempts after 'upload_time' filter: {len(attempts)}")
    
    # Sample 100 distinct registration_form_id values
    unique_ids = attempts['registration_form_id'].unique()
    sampled_ids = pd.Series(unique_ids).sample(n=100, random_state=42).values

    # Filter attempts to keep only those sampled IDs
    attempts = attempts[attempts['registration_form_id'].isin(sampled_ids)]
    print(f"Sampled attempts rows after filtering by distinct registration_form_id (count may be >100 due to duplicates): {len(attempts)}")
    print(f"Distinct registration_form_id in sampled attempts: {attempts['registration_form_id'].nunique()}")
    print(f"Sample registration_form_id: {attempts['registration_form_id'].unique()}")

    # Continue with rest of processing (load model, process chunks, etc.)
    model = joblib.load(model_path)
    
    # Load or initialize progress tracking
    progress = load_progress()

    chunks_processed = 0
    total_chunks = None  # Optional: set if you want to know total chunks

    # Iterate over voter file chunks from DB
    for idx, vf_chunk in enumerate(load_voterfile_chunk(db_engine, sql, chunksize=chunksize)):
        if str(idx) in progress:
            print(f"Chunk {idx}: already processed, skipping")
            continue

        print(f"Chunk {idx}: processing ...")

        # Rename columns in voterfile chunk
        vf_chunk = vf_chunk.rename(columns={
            "first_name": "first_name_vf",
            "last_name": "last_name_vf",
            "residence_zipcode": "zip_raw_vf",
            "birth_date": "dob_raw_vf",
        })

        # Normalize keys in both attempts and voterfile chunks
        attempts_norm, vf_chunk_norm = add_normalized_keys(attempts, vf_chunk)

        # Generate candidate pairs by blocking
        candidates = block_candidate_pairs(attempts_norm, vf_chunk_norm)
        print(f"Chunk {idx}: Generated {len(candidates)} candidate pairs")
        print(f"Chunk {idx}: Unique registration_form_id in candidates: {candidates['registration_form_id'].nunique() if not candidates.empty else 0}")

        # Skip empty candidate chunks
        if candidates.empty:
            print(f"Chunk {idx}: No candidate pairs generated, skipping feature build and prediction")
            progress[str(idx)] = True
            save_progress(progress)
            continue

        # Compute features for candidate pairs
        X, _ = add_features(candidates)
        print(f"Chunk {idx}: Features computed for {X.shape[0]} candidates")

        # Predict match probabilities using the loaded model
        probs = predict_chunk(model, X)
        candidates['match_prob'] = probs
        print(f"Chunk {idx}: Predictions made")

        # Save chunk results and update progress
        save_chunk_results(candidates, idx)
        progress[str(idx)] = True
        save_progress(progress)
        chunks_processed += 1

    print(f"Processing complete. Total chunks processed: {chunks_processed}")

    # Optional: clear progress file if all done
    # if total_chunks and chunks_processed == total_chunks:
    #     os.remove(PROGRESS_FILE)
    #     print("All chunks processed. Progress file deleted.")
# Out:
# Repo root added to sys.path: /Users/borismartinez/Documents/GitHub/engage

# %%
import os
import matching.utils.db as db

db_engine = db.get_engine()
attempts_path = "/Users/borismartinez/Documents/GitHub/engage/data/vr_blocks_export_no_na.csv"
sql = "SELECT * FROM voterfile.election_detail_2024 WHERE county = 'DAD'"

# Correct: model_path should point to your trained model file, NOT metrics JSON
model_path = "/Users/borismartinez/Documents/GitHub/engage/models/xgboost_model.pkl"

chunksize = 5000
output_dir = "/Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype"

if os.path.exists(output_dir):
    for f in os.listdir(output_dir):
        if f.startswith("predicted_matches_chunk_prototype") and f.endswith(".csv"):
            os.remove(os.path.join(output_dir, f))
else:
    os.makedirs(output_dir)

stream_inference(
    attempts_path=attempts_path,
    db_engine=db_engine,
    sql=sql,
    model_path=model_path,
    chunksize=chunksize
)
# Out:
# /Users/borismartinez/Documents/GitHub/engage/matching/loaders/load_attempts.py:12: DtypeWarning: Columns (5,14,15,16,17,18,22,25,32,36,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path)
# Attempts after required columns filter: 51008
# Attempts after 'upload_time' filter: 25570
# Sampled attempts rows after filtering by distinct registration_form_id (count may be >100 due to duplicates): 100
# Distinct registration_form_id in sampled attempts: 100
# Sample registration_form_id: [   6001287364    6001287712    6001285689 1010000008304 1010000005734
#  1010000005010 1010000010099 1010000010671 1010000012411 1010000012272
#  1010000016738 1010000019164 1010000019201 1010000019216 1010000028123
#  1010000026446 1010000029903 1010000029892 1010000030854 1010000027402
#  1010000035189 1010000033670 1010000054438 1010000060861 1010000072639
#  1010000003612 1010000003575 1010000116656 1010000163458 1010000457595
#  1010000224980 1010000241914 1010000262561 1010000262988 1010000337809
#  1010000383112 1010000388172 1010000394362 1010000394365 1010000410531
#  1010000415562 1010000422151 1010000421770 1010000444592 1010000445000
#  1010000454972 1010000478258 1010000486694 1010000499812 1010000519156
#  1010000540217 1010000540532 1010000543916 1010000544976 1010000556775
#  1010000577633 1010000545838 1010000582454 1010000625409 1010000626635
#  1010000604262 1010000582352 1010000625966 1010000625971 1010000643601
#  1010000673718 1010000681935 1010000681862 1010000681507 1010000704201
#  1010000714741 1010000749644 1010000756414 1010000760830 1010000775030
#  1010000776327 1010000840305 1010000778677 1010000785542 1010000807586
#  1010000825677 1010000815881 1010000815426 1010000815233 1010000813105
#  1010000835031 1010000861636 1010000863916 1010000863841 1010000872983
#  1010000883992 1010000883736 1010000884687 1010000904604 1010000904628
#  1010000891543 1010000982655 1010000980237 1010000980797 1010000981440]
# Chunk 0: processing ...
# Chunk 0: Generated 282 candidate pairs
# Chunk 0: Unique registration_form_id in candidates: 64
# add_features: processing chunk with 282 rows
# Chunk 0: Features computed for 282 candidates
# Chunk 0: Predictions made
# Chunk 0: Saved 282 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_0.csv
# Chunk 1: processing ...
# Chunk 1: Generated 323 candidate pairs
# Chunk 1: Unique registration_form_id in candidates: 69
# add_features: processing chunk with 323 rows
# Chunk 1: Features computed for 323 candidates
# Chunk 1: Predictions made
# Chunk 1: Saved 323 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_1.csv
# Chunk 2: processing ...
# Chunk 2: Generated 371 candidate pairs
# Chunk 2: Unique registration_form_id in candidates: 75
# add_features: processing chunk with 371 rows
# Chunk 2: Features computed for 371 candidates
# Chunk 2: Predictions made
# Chunk 2: Saved 371 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_2.csv
# Chunk 3: processing ...
# Chunk 3: Generated 279 candidate pairs
# Chunk 3: Unique registration_form_id in candidates: 65
# add_features: processing chunk with 279 rows
# Chunk 3: Features computed for 279 candidates
# Chunk 3: Predictions made
# Chunk 3: Saved 279 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_3.csv
# Chunk 4: processing ...
# Chunk 4: Generated 391 candidate pairs
# Chunk 4: Unique registration_form_id in candidates: 74
# add_features: processing chunk with 391 rows
# Chunk 4: Features computed for 391 candidates
# Chunk 4: Predictions made
# Chunk 4: Saved 391 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_4.csv
# Chunk 5: processing ...
# Chunk 5: Generated 370 candidate pairs
# Chunk 5: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 370 rows
# Chunk 5: Features computed for 370 candidates
# Chunk 5: Predictions made
# Chunk 5: Saved 370 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_5.csv
# Chunk 6: processing ...
# Chunk 6: Generated 401 candidate pairs
# Chunk 6: Unique registration_form_id in candidates: 79
# add_features: processing chunk with 401 rows
# Chunk 6: Features computed for 401 candidates
# Chunk 6: Predictions made
# Chunk 6: Saved 401 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_6.csv
# Chunk 7: processing ...
# Chunk 7: Generated 233 candidate pairs
# Chunk 7: Unique registration_form_id in candidates: 64
# add_features: processing chunk with 233 rows
# Chunk 7: Features computed for 233 candidates
# Chunk 7: Predictions made
# Chunk 7: Saved 233 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_7.csv
# Chunk 8: processing ...
# Chunk 8: Generated 235 candidate pairs
# Chunk 8: Unique registration_form_id in candidates: 55
# add_features: processing chunk with 235 rows
# Chunk 8: Features computed for 235 candidates
# Chunk 8: Predictions made
# Chunk 8: Saved 235 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_8.csv
# Chunk 9: processing ...
# Chunk 9: Generated 191 candidate pairs
# Chunk 9: Unique registration_form_id in candidates: 52
# add_features: processing chunk with 191 rows
# Chunk 9: Features computed for 191 candidates
# Chunk 9: Predictions made
# Chunk 9: Saved 191 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_9.csv
# Chunk 10: processing ...
# Chunk 10: Generated 171 candidate pairs
# Chunk 10: Unique registration_form_id in candidates: 45
# add_features: processing chunk with 171 rows
# Chunk 10: Features computed for 171 candidates
# Chunk 10: Predictions made
# Chunk 10: Saved 171 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_10.csv
# Chunk 11: processing ...
# Chunk 11: Generated 152 candidate pairs
# Chunk 11: Unique registration_form_id in candidates: 52
# add_features: processing chunk with 152 rows
# Chunk 11: Features computed for 152 candidates
# Chunk 11: Predictions made
# Chunk 11: Saved 152 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_11.csv
# Chunk 12: processing ...
# Chunk 12: Generated 179 candidate pairs
# Chunk 12: Unique registration_form_id in candidates: 54
# add_features: processing chunk with 179 rows
# Chunk 12: Features computed for 179 candidates
# Chunk 12: Predictions made
# Chunk 12: Saved 179 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_12.csv
# Chunk 13: processing ...
# Chunk 13: Generated 279 candidate pairs
# Chunk 13: Unique registration_form_id in candidates: 72
# add_features: processing chunk with 279 rows
# Chunk 13: Features computed for 279 candidates
# Chunk 13: Predictions made
# Chunk 13: Saved 279 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_13.csv
# Chunk 14: processing ...
# Chunk 14: Generated 434 candidate pairs
# Chunk 14: Unique registration_form_id in candidates: 77
# add_features: processing chunk with 434 rows
# Chunk 14: Features computed for 434 candidates
# Chunk 14: Predictions made
# Chunk 14: Saved 434 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_14.csv
# Chunk 15: processing ...
# Chunk 15: Generated 345 candidate pairs
# Chunk 15: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 345 rows
# Chunk 15: Features computed for 345 candidates
# Chunk 15: Predictions made
# Chunk 15: Saved 345 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_15.csv
# Chunk 16: processing ...
# Chunk 16: Generated 421 candidate pairs
# Chunk 16: Unique registration_form_id in candidates: 73
# add_features: processing chunk with 421 rows
# Chunk 16: Features computed for 421 candidates
# Chunk 16: Predictions made
# Chunk 16: Saved 421 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_16.csv
# Chunk 17: processing ...
# Chunk 17: Generated 543 candidate pairs
# Chunk 17: Unique registration_form_id in candidates: 73
# add_features: processing chunk with 543 rows
# Chunk 17: Features computed for 543 candidates
# Chunk 17: Predictions made
# Chunk 17: Saved 543 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_17.csv
# Chunk 18: processing ...
# Chunk 18: Generated 268 candidate pairs
# Chunk 18: Unique registration_form_id in candidates: 62
# add_features: processing chunk with 268 rows
# Chunk 18: Features computed for 268 candidates
# Chunk 18: Predictions made
# Chunk 18: Saved 268 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_18.csv
# Chunk 19: processing ...
# Chunk 19: Generated 266 candidate pairs
# Chunk 19: Unique registration_form_id in candidates: 60
# add_features: processing chunk with 266 rows
# Chunk 19: Features computed for 266 candidates
# Chunk 19: Predictions made
# Chunk 19: Saved 266 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_19.csv
# Chunk 20: processing ...
# Chunk 20: Generated 296 candidate pairs
# Chunk 20: Unique registration_form_id in candidates: 63
# add_features: processing chunk with 296 rows
# Chunk 20: Features computed for 296 candidates
# Chunk 20: Predictions made
# Chunk 20: Saved 296 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_20.csv
# Chunk 21: processing ...
# Chunk 21: Generated 255 candidate pairs
# Chunk 21: Unique registration_form_id in candidates: 74
# add_features: processing chunk with 255 rows
# Chunk 21: Features computed for 255 candidates
# Chunk 21: Predictions made
# Chunk 21: Saved 255 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_21.csv
# Chunk 22: processing ...
# Chunk 22: Generated 225 candidate pairs
# Chunk 22: Unique registration_form_id in candidates: 66
# add_features: processing chunk with 225 rows
# Chunk 22: Features computed for 225 candidates
# Chunk 22: Predictions made
# Chunk 22: Saved 225 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_22.csv
# Chunk 23: processing ...
# Chunk 23: Generated 294 candidate pairs
# Chunk 23: Unique registration_form_id in candidates: 65
# add_features: processing chunk with 294 rows
# Chunk 23: Features computed for 294 candidates
# Chunk 23: Predictions made
# Chunk 23: Saved 294 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_23.csv
# Chunk 24: processing ...
# Chunk 24: Generated 237 candidate pairs
# Chunk 24: Unique registration_form_id in candidates: 69
# add_features: processing chunk with 237 rows
# Chunk 24: Features computed for 237 candidates
# Chunk 24: Predictions made
# Chunk 24: Saved 237 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_24.csv
# Chunk 25: processing ...
# Chunk 25: Generated 208 candidate pairs
# Chunk 25: Unique registration_form_id in candidates: 62
# add_features: processing chunk with 208 rows
# Chunk 25: Features computed for 208 candidates
# Chunk 25: Predictions made
# Chunk 25: Saved 208 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_25.csv
# Chunk 26: processing ...
# Chunk 26: Generated 173 candidate pairs
# Chunk 26: Unique registration_form_id in candidates: 46
# add_features: processing chunk with 173 rows
# Chunk 26: Features computed for 173 candidates
# Chunk 26: Predictions made
# Chunk 26: Saved 173 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_26.csv
# Chunk 27: processing ...
# Chunk 27: Generated 198 candidate pairs
# Chunk 27: Unique registration_form_id in candidates: 45
# add_features: processing chunk with 198 rows
# Chunk 27: Features computed for 198 candidates
# Chunk 27: Predictions made
# Chunk 27: Saved 198 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_27.csv
# Chunk 28: processing ...
# Chunk 28: Generated 188 candidate pairs
# Chunk 28: Unique registration_form_id in candidates: 58
# add_features: processing chunk with 188 rows
# Chunk 28: Features computed for 188 candidates
# Chunk 28: Predictions made
# Chunk 28: Saved 188 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_28.csv
# Chunk 29: processing ...
# Chunk 29: Generated 201 candidate pairs
# Chunk 29: Unique registration_form_id in candidates: 65
# add_features: processing chunk with 201 rows
# Chunk 29: Features computed for 201 candidates
# Chunk 29: Predictions made
# Chunk 29: Saved 201 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_29.csv
# Chunk 30: processing ...
# Chunk 30: Generated 196 candidate pairs
# Chunk 30: Unique registration_form_id in candidates: 63
# add_features: processing chunk with 196 rows
# Chunk 30: Features computed for 196 candidates
# Chunk 30: Predictions made
# Chunk 30: Saved 196 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_30.csv
# Chunk 31: processing ...
# Chunk 31: Generated 216 candidate pairs
# Chunk 31: Unique registration_form_id in candidates: 71
# add_features: processing chunk with 216 rows
# Chunk 31: Features computed for 216 candidates
# Chunk 31: Predictions made
# Chunk 31: Saved 216 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_31.csv
# Chunk 32: processing ...
# Chunk 32: Generated 235 candidate pairs
# Chunk 32: Unique registration_form_id in candidates: 69
# add_features: processing chunk with 235 rows
# Chunk 32: Features computed for 235 candidates
# Chunk 32: Predictions made
# Chunk 32: Saved 235 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_32.csv
# Chunk 33: processing ...
# Chunk 33: Generated 285 candidate pairs
# Chunk 33: Unique registration_form_id in candidates: 69
# add_features: processing chunk with 285 rows
# Chunk 33: Features computed for 285 candidates
# Chunk 33: Predictions made
# Chunk 33: Saved 285 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_33.csv
# Chunk 34: processing ...
# Chunk 34: Generated 264 candidate pairs
# Chunk 34: Unique registration_form_id in candidates: 70
# add_features: processing chunk with 264 rows
# Chunk 34: Features computed for 264 candidates
# Chunk 34: Predictions made
# Chunk 34: Saved 264 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_34.csv
# Chunk 35: processing ...
# Chunk 35: Generated 369 candidate pairs
# Chunk 35: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 369 rows
# Chunk 35: Features computed for 369 candidates
# Chunk 35: Predictions made
# Chunk 35: Saved 369 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_35.csv
# Chunk 36: processing ...
# Chunk 36: Generated 480 candidate pairs
# Chunk 36: Unique registration_form_id in candidates: 77
# add_features: processing chunk with 480 rows
# Chunk 36: Features computed for 480 candidates
# Chunk 36: Predictions made
# Chunk 36: Saved 480 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_36.csv
# Chunk 37: processing ...
# Chunk 37: Generated 473 candidate pairs
# Chunk 37: Unique registration_form_id in candidates: 74
# add_features: processing chunk with 473 rows
# Chunk 37: Features computed for 473 candidates
# Chunk 37: Predictions made
# Chunk 37: Saved 473 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_37.csv
# Chunk 38: processing ...
# Chunk 38: Generated 490 candidate pairs
# Chunk 38: Unique registration_form_id in candidates: 78
# add_features: processing chunk with 490 rows
# Chunk 38: Features computed for 490 candidates
# Chunk 38: Predictions made
# Chunk 38: Saved 490 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_38.csv
# Chunk 39: processing ...
# Chunk 39: Generated 445 candidate pairs
# Chunk 39: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 445 rows
# Chunk 39: Features computed for 445 candidates
# Chunk 39: Predictions made
# Chunk 39: Saved 445 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_39.csv
# Chunk 40: processing ...
# Chunk 40: Generated 338 candidate pairs
# Chunk 40: Unique registration_form_id in candidates: 75
# add_features: processing chunk with 338 rows
# Chunk 40: Features computed for 338 candidates
# Chunk 40: Predictions made
# Chunk 40: Saved 338 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_40.csv
# Chunk 41: processing ...
# Chunk 41: Generated 299 candidate pairs
# Chunk 41: Unique registration_form_id in candidates: 69
# add_features: processing chunk with 299 rows
# Chunk 41: Features computed for 299 candidates
# Chunk 41: Predictions made
# Chunk 41: Saved 299 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_41.csv
# Chunk 42: processing ...
# Chunk 42: Generated 300 candidate pairs
# Chunk 42: Unique registration_form_id in candidates: 70
# add_features: processing chunk with 300 rows
# Chunk 42: Features computed for 300 candidates
# Chunk 42: Predictions made
# Chunk 42: Saved 300 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_42.csv
# Chunk 43: processing ...
# Chunk 43: Generated 305 candidate pairs
# Chunk 43: Unique registration_form_id in candidates: 71
# add_features: processing chunk with 305 rows
# Chunk 43: Features computed for 305 candidates
# Chunk 43: Predictions made
# Chunk 43: Saved 305 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_43.csv
# Chunk 44: processing ...
# Chunk 44: Generated 300 candidate pairs
# Chunk 44: Unique registration_form_id in candidates: 72
# add_features: processing chunk with 300 rows
# Chunk 44: Features computed for 300 candidates
# Chunk 44: Predictions made
# Chunk 44: Saved 300 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_44.csv
# Chunk 45: processing ...
# Chunk 45: Generated 245 candidate pairs
# Chunk 45: Unique registration_form_id in candidates: 61
# add_features: processing chunk with 245 rows
# Chunk 45: Features computed for 245 candidates
# Chunk 45: Predictions made
# Chunk 45: Saved 245 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_45.csv
# Chunk 46: processing ...
# Chunk 46: Generated 219 candidate pairs
# Chunk 46: Unique registration_form_id in candidates: 63
# add_features: processing chunk with 219 rows
# Chunk 46: Features computed for 219 candidates
# Chunk 46: Predictions made
# Chunk 46: Saved 219 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_46.csv
# Chunk 47: processing ...
# Chunk 47: Generated 258 candidate pairs
# Chunk 47: Unique registration_form_id in candidates: 64
# add_features: processing chunk with 258 rows
# Chunk 47: Features computed for 258 candidates
# Chunk 47: Predictions made
# Chunk 47: Saved 258 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_47.csv
# Chunk 48: processing ...
# Chunk 48: Generated 286 candidate pairs
# Chunk 48: Unique registration_form_id in candidates: 58
# add_features: processing chunk with 286 rows
# Chunk 48: Features computed for 286 candidates
# Chunk 48: Predictions made
# Chunk 48: Saved 286 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_48.csv
# Chunk 49: processing ...
# Chunk 49: Generated 289 candidate pairs
# Chunk 49: Unique registration_form_id in candidates: 65
# add_features: processing chunk with 289 rows
# Chunk 49: Features computed for 289 candidates
# Chunk 49: Predictions made
# Chunk 49: Saved 289 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_49.csv
# Chunk 50: processing ...
# Chunk 50: Generated 331 candidate pairs
# Chunk 50: Unique registration_form_id in candidates: 55
# add_features: processing chunk with 331 rows
# Chunk 50: Features computed for 331 candidates
# Chunk 50: Predictions made
# Chunk 50: Saved 331 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_50.csv
# Chunk 51: processing ...
# Chunk 51: Generated 333 candidate pairs
# Chunk 51: Unique registration_form_id in candidates: 68
# add_features: processing chunk with 333 rows
# Chunk 51: Features computed for 333 candidates
# Chunk 51: Predictions made
# Chunk 51: Saved 333 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_51.csv
# Chunk 52: processing ...
# Chunk 52: Generated 295 candidate pairs
# Chunk 52: Unique registration_form_id in candidates: 60
# add_features: processing chunk with 295 rows
# Chunk 52: Features computed for 295 candidates
# Chunk 52: Predictions made
# Chunk 52: Saved 295 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_52.csv
# Chunk 53: processing ...
# Chunk 53: Generated 268 candidate pairs
# Chunk 53: Unique registration_form_id in candidates: 62
# add_features: processing chunk with 268 rows
# Chunk 53: Features computed for 268 candidates
# Chunk 53: Predictions made
# Chunk 53: Saved 268 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_53.csv
# Chunk 54: processing ...
# Chunk 54: Generated 259 candidate pairs
# Chunk 54: Unique registration_form_id in candidates: 66
# add_features: processing chunk with 259 rows
# Chunk 54: Features computed for 259 candidates
# Chunk 54: Predictions made
# Chunk 54: Saved 259 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_54.csv
# Chunk 55: processing ...
# Chunk 55: Generated 245 candidate pairs
# Chunk 55: Unique registration_form_id in candidates: 65
# add_features: processing chunk with 245 rows
# Chunk 55: Features computed for 245 candidates
# Chunk 55: Predictions made
# Chunk 55: Saved 245 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_55.csv
# Chunk 56: processing ...
# Chunk 56: Generated 241 candidate pairs
# Chunk 56: Unique registration_form_id in candidates: 66
# add_features: processing chunk with 241 rows
# Chunk 56: Features computed for 241 candidates
# Chunk 56: Predictions made
# Chunk 56: Saved 241 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_56.csv
# Chunk 57: processing ...
# Chunk 57: Generated 240 candidate pairs
# Chunk 57: Unique registration_form_id in candidates: 70
# add_features: processing chunk with 240 rows
# Chunk 57: Features computed for 240 candidates
# Chunk 57: Predictions made
# Chunk 57: Saved 240 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_57.csv
# Chunk 58: processing ...
# Chunk 58: Generated 217 candidate pairs
# Chunk 58: Unique registration_form_id in candidates: 70
# add_features: processing chunk with 217 rows
# Chunk 58: Features computed for 217 candidates
# Chunk 58: Predictions made
# Chunk 58: Saved 217 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_58.csv
# Chunk 59: processing ...
# Chunk 59: Generated 247 candidate pairs
# Chunk 59: Unique registration_form_id in candidates: 70
# add_features: processing chunk with 247 rows
# Chunk 59: Features computed for 247 candidates
# Chunk 59: Predictions made
# Chunk 59: Saved 247 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_59.csv
# Chunk 60: processing ...
# Chunk 60: Generated 251 candidate pairs
# Chunk 60: Unique registration_form_id in candidates: 69
# add_features: processing chunk with 251 rows
# Chunk 60: Features computed for 251 candidates
# Chunk 60: Predictions made
# Chunk 60: Saved 251 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_60.csv
# Chunk 61: processing ...
# Chunk 61: Generated 276 candidate pairs
# Chunk 61: Unique registration_form_id in candidates: 73
# add_features: processing chunk with 276 rows
# Chunk 61: Features computed for 276 candidates
# Chunk 61: Predictions made
# Chunk 61: Saved 276 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_61.csv
# Chunk 62: processing ...
# Chunk 62: Generated 365 candidate pairs
# Chunk 62: Unique registration_form_id in candidates: 72
# add_features: processing chunk with 365 rows
# Chunk 62: Features computed for 365 candidates
# Chunk 62: Predictions made
# Chunk 62: Saved 365 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_62.csv
# Chunk 63: processing ...
# Chunk 63: Generated 366 candidate pairs
# Chunk 63: Unique registration_form_id in candidates: 75
# add_features: processing chunk with 366 rows
# Chunk 63: Features computed for 366 candidates
# Chunk 63: Predictions made
# Chunk 63: Saved 366 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_63.csv
# Chunk 64: processing ...
# Chunk 64: Generated 342 candidate pairs
# Chunk 64: Unique registration_form_id in candidates: 74
# add_features: processing chunk with 342 rows
# Chunk 64: Features computed for 342 candidates
# Chunk 64: Predictions made
# Chunk 64: Saved 342 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_64.csv
# Chunk 65: processing ...
# Chunk 65: Generated 328 candidate pairs
# Chunk 65: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 328 rows
# Chunk 65: Features computed for 328 candidates
# Chunk 65: Predictions made
# Chunk 65: Saved 328 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_65.csv
# Chunk 66: processing ...
# Chunk 66: Generated 492 candidate pairs
# Chunk 66: Unique registration_form_id in candidates: 75
# add_features: processing chunk with 492 rows
# Chunk 66: Features computed for 492 candidates
# Chunk 66: Predictions made
# Chunk 66: Saved 492 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_66.csv
# Chunk 67: processing ...
# Chunk 67: Generated 285 candidate pairs
# Chunk 67: Unique registration_form_id in candidates: 77
# add_features: processing chunk with 285 rows
# Chunk 67: Features computed for 285 candidates
# Chunk 67: Predictions made
# Chunk 67: Saved 285 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_67.csv
# Chunk 68: processing ...
# Chunk 68: Generated 297 candidate pairs
# Chunk 68: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 297 rows
# Chunk 68: Features computed for 297 candidates
# Chunk 68: Predictions made
# Chunk 68: Saved 297 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_68.csv
# Chunk 69: processing ...
# Chunk 69: Generated 324 candidate pairs
# Chunk 69: Unique registration_form_id in candidates: 72
# add_features: processing chunk with 324 rows
# Chunk 69: Features computed for 324 candidates
# Chunk 69: Predictions made
# Chunk 69: Saved 324 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_69.csv
# Chunk 70: processing ...
# Chunk 70: Generated 343 candidate pairs
# Chunk 70: Unique registration_form_id in candidates: 75
# add_features: processing chunk with 343 rows
# Chunk 70: Features computed for 343 candidates
# Chunk 70: Predictions made
# Chunk 70: Saved 343 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_70.csv
# Chunk 71: processing ...
# Chunk 71: Generated 318 candidate pairs
# Chunk 71: Unique registration_form_id in candidates: 71
# add_features: processing chunk with 318 rows
# Chunk 71: Features computed for 318 candidates
# Chunk 71: Predictions made
# Chunk 71: Saved 318 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_71.csv
# Chunk 72: processing ...
# Chunk 72: Generated 275 candidate pairs
# Chunk 72: Unique registration_form_id in candidates: 73
# add_features: processing chunk with 275 rows
# Chunk 72: Features computed for 275 candidates
# Chunk 72: Predictions made
# Chunk 72: Saved 275 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_72.csv
# Chunk 73: processing ...
# Chunk 73: Generated 341 candidate pairs
# Chunk 73: Unique registration_form_id in candidates: 78
# add_features: processing chunk with 341 rows
# Chunk 73: Features computed for 341 candidates
# Chunk 73: Predictions made
# Chunk 73: Saved 341 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_73.csv
# Chunk 74: processing ...
# Chunk 74: Generated 295 candidate pairs
# Chunk 74: Unique registration_form_id in candidates: 77
# add_features: processing chunk with 295 rows
# Chunk 74: Features computed for 295 candidates
# Chunk 74: Predictions made
# Chunk 74: Saved 295 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_74.csv
# Chunk 75: processing ...
# Chunk 75: Generated 310 candidate pairs
# Chunk 75: Unique registration_form_id in candidates: 72
# add_features: processing chunk with 310 rows
# Chunk 75: Features computed for 310 candidates
# Chunk 75: Predictions made
# Chunk 75: Saved 310 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_75.csv
# Chunk 76: processing ...
# Chunk 76: Generated 270 candidate pairs
# Chunk 76: Unique registration_form_id in candidates: 74
# add_features: processing chunk with 270 rows
# Chunk 76: Features computed for 270 candidates
# Chunk 76: Predictions made
# Chunk 76: Saved 270 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_76.csv
# Chunk 77: processing ...
# Chunk 77: Generated 317 candidate pairs
# Chunk 77: Unique registration_form_id in candidates: 75
# add_features: processing chunk with 317 rows
# Chunk 77: Features computed for 317 candidates
# Chunk 77: Predictions made
# Chunk 77: Saved 317 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_77.csv
# Chunk 78: processing ...
# Chunk 78: Generated 289 candidate pairs
# Chunk 78: Unique registration_form_id in candidates: 71
# add_features: processing chunk with 289 rows
# Chunk 78: Features computed for 289 candidates
# Chunk 78: Predictions made
# Chunk 78: Saved 289 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_78.csv
# Chunk 79: processing ...
# Chunk 79: Generated 333 candidate pairs
# Chunk 79: Unique registration_form_id in candidates: 74
# add_features: processing chunk with 333 rows
# Chunk 79: Features computed for 333 candidates
# Chunk 79: Predictions made
# Chunk 79: Saved 333 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_79.csv
# Chunk 80: processing ...
# Chunk 80: Generated 335 candidate pairs
# Chunk 80: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 335 rows
# Chunk 80: Features computed for 335 candidates
# Chunk 80: Predictions made
# Chunk 80: Saved 335 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_80.csv
# Chunk 81: processing ...
# Chunk 81: Generated 268 candidate pairs
# Chunk 81: Unique registration_form_id in candidates: 72
# add_features: processing chunk with 268 rows
# Chunk 81: Features computed for 268 candidates
# Chunk 81: Predictions made
# Chunk 81: Saved 268 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_81.csv
# Chunk 82: processing ...
# Chunk 82: Generated 348 candidate pairs
# Chunk 82: Unique registration_form_id in candidates: 79
# add_features: processing chunk with 348 rows
# Chunk 82: Features computed for 348 candidates
# Chunk 82: Predictions made
# Chunk 82: Saved 348 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_82.csv
# Chunk 83: processing ...
# Chunk 83: Generated 283 candidate pairs
# Chunk 83: Unique registration_form_id in candidates: 71
# add_features: processing chunk with 283 rows
# Chunk 83: Features computed for 283 candidates
# Chunk 83: Predictions made
# Chunk 83: Saved 283 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_83.csv
# Chunk 84: processing ...
# Chunk 84: Generated 302 candidate pairs
# Chunk 84: Unique registration_form_id in candidates: 74
# add_features: processing chunk with 302 rows
# Chunk 84: Features computed for 302 candidates
# Chunk 84: Predictions made
# Chunk 84: Saved 302 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_84.csv
# Chunk 85: processing ...
# Chunk 85: Generated 350 candidate pairs
# Chunk 85: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 350 rows
# Chunk 85: Features computed for 350 candidates
# Chunk 85: Predictions made
# Chunk 85: Saved 350 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_85.csv
# Chunk 86: processing ...
# Chunk 86: Generated 338 candidate pairs
# Chunk 86: Unique registration_form_id in candidates: 75
# add_features: processing chunk with 338 rows
# Chunk 86: Features computed for 338 candidates
# Chunk 86: Predictions made
# Chunk 86: Saved 338 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_86.csv
# Chunk 87: processing ...
# Chunk 87: Generated 325 candidate pairs
# Chunk 87: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 325 rows
# Chunk 87: Features computed for 325 candidates
# Chunk 87: Predictions made
# Chunk 87: Saved 325 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_87.csv
# Chunk 88: processing ...
# Chunk 88: Generated 333 candidate pairs
# Chunk 88: Unique registration_form_id in candidates: 72
# add_features: processing chunk with 333 rows
# Chunk 88: Features computed for 333 candidates
# Chunk 88: Predictions made
# Chunk 88: Saved 333 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_88.csv
# Chunk 89: processing ...
# Chunk 89: Generated 316 candidate pairs
# Chunk 89: Unique registration_form_id in candidates: 73
# add_features: processing chunk with 316 rows
# Chunk 89: Features computed for 316 candidates
# Chunk 89: Predictions made
# Chunk 89: Saved 316 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_89.csv
# Chunk 90: processing ...
# Chunk 90: Generated 283 candidate pairs
# Chunk 90: Unique registration_form_id in candidates: 79
# add_features: processing chunk with 283 rows
# Chunk 90: Features computed for 283 candidates
# Chunk 90: Predictions made
# Chunk 90: Saved 283 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_90.csv
# Chunk 91: processing ...
# Chunk 91: Generated 351 candidate pairs
# Chunk 91: Unique registration_form_id in candidates: 74
# add_features: processing chunk with 351 rows
# Chunk 91: Features computed for 351 candidates
# Chunk 91: Predictions made
# Chunk 91: Saved 351 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_91.csv
# Chunk 92: processing ...
# Chunk 92: Generated 327 candidate pairs
# Chunk 92: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 327 rows
# Chunk 92: Features computed for 327 candidates
# Chunk 92: Predictions made
# Chunk 92: Saved 327 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_92.csv
# Chunk 93: processing ...
# Chunk 93: Generated 291 candidate pairs
# Chunk 93: Unique registration_form_id in candidates: 73
# add_features: processing chunk with 291 rows
# Chunk 93: Features computed for 291 candidates
# Chunk 93: Predictions made
# Chunk 93: Saved 291 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_93.csv
# Chunk 94: processing ...
# Chunk 94: Generated 310 candidate pairs
# Chunk 94: Unique registration_form_id in candidates: 68
# add_features: processing chunk with 310 rows
# Chunk 94: Features computed for 310 candidates
# Chunk 94: Predictions made
# Chunk 94: Saved 310 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_94.csv
# Chunk 95: processing ...
# Chunk 95: Generated 244 candidate pairs
# Chunk 95: Unique registration_form_id in candidates: 66
# add_features: processing chunk with 244 rows
# Chunk 95: Features computed for 244 candidates
# Chunk 95: Predictions made
# Chunk 95: Saved 244 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_95.csv
# Chunk 96: processing ...
# Chunk 96: Generated 370 candidate pairs
# Chunk 96: Unique registration_form_id in candidates: 69
# add_features: processing chunk with 370 rows
# Chunk 96: Features computed for 370 candidates
# Chunk 96: Predictions made
# Chunk 96: Saved 370 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_96.csv
# Chunk 97: processing ...
# Chunk 97: Generated 316 candidate pairs
# Chunk 97: Unique registration_form_id in candidates: 69
# add_features: processing chunk with 316 rows
# Chunk 97: Features computed for 316 candidates
# Chunk 97: Predictions made
# Chunk 97: Saved 316 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_97.csv
# Chunk 98: processing ...
# Chunk 98: Generated 186 candidate pairs
# Chunk 98: Unique registration_form_id in candidates: 48
# add_features: processing chunk with 186 rows
# Chunk 98: Features computed for 186 candidates
# Chunk 98: Predictions made
# Chunk 98: Saved 186 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_98.csv
# Chunk 99: processing ...
# Chunk 99: Generated 341 candidate pairs
# Chunk 99: Unique registration_form_id in candidates: 77
# add_features: processing chunk with 341 rows
# Chunk 99: Features computed for 341 candidates
# Chunk 99: Predictions made
# Chunk 99: Saved 341 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_99.csv
# Chunk 100: processing ...
# Chunk 100: Generated 367 candidate pairs
# Chunk 100: Unique registration_form_id in candidates: 72
# add_features: processing chunk with 367 rows
# Chunk 100: Features computed for 367 candidates
# Chunk 100: Predictions made
# Chunk 100: Saved 367 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_100.csv
# Chunk 101: processing ...
# Chunk 101: Generated 399 candidate pairs
# Chunk 101: Unique registration_form_id in candidates: 75
# add_features: processing chunk with 399 rows
# Chunk 101: Features computed for 399 candidates
# Chunk 101: Predictions made
# Chunk 101: Saved 399 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_101.csv
# Chunk 102: processing ...
# Chunk 102: Generated 360 candidate pairs
# Chunk 102: Unique registration_form_id in candidates: 73
# add_features: processing chunk with 360 rows
# Chunk 102: Features computed for 360 candidates
# Chunk 102: Predictions made
# Chunk 102: Saved 360 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_102.csv
# Chunk 103: processing ...
# Chunk 103: Generated 231 candidate pairs
# Chunk 103: Unique registration_form_id in candidates: 56
# add_features: processing chunk with 231 rows
# Chunk 103: Features computed for 231 candidates
# Chunk 103: Predictions made
# Chunk 103: Saved 231 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_103.csv
# Chunk 104: processing ...
# Chunk 104: Generated 198 candidate pairs
# Chunk 104: Unique registration_form_id in candidates: 55
# add_features: processing chunk with 198 rows
# Chunk 104: Features computed for 198 candidates
# Chunk 104: Predictions made
# Chunk 104: Saved 198 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_104.csv
# Chunk 105: processing ...
# Chunk 105: Generated 262 candidate pairs
# Chunk 105: Unique registration_form_id in candidates: 68
# add_features: processing chunk with 262 rows
# Chunk 105: Features computed for 262 candidates
# Chunk 105: Predictions made
# Chunk 105: Saved 262 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_105.csv
# Chunk 106: processing ...
# Chunk 106: Generated 270 candidate pairs
# Chunk 106: Unique registration_form_id in candidates: 73
# add_features: processing chunk with 270 rows
# Chunk 106: Features computed for 270 candidates
# Chunk 106: Predictions made
# Chunk 106: Saved 270 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_106.csv
# Chunk 107: processing ...
# Chunk 107: Generated 392 candidate pairs
# Chunk 107: Unique registration_form_id in candidates: 77
# add_features: processing chunk with 392 rows
# Chunk 107: Features computed for 392 candidates
# Chunk 107: Predictions made
# Chunk 107: Saved 392 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_107.csv
# Chunk 108: processing ...
# Chunk 108: Generated 344 candidate pairs
# Chunk 108: Unique registration_form_id in candidates: 75
# add_features: processing chunk with 344 rows
# Chunk 108: Features computed for 344 candidates
# Chunk 108: Predictions made
# Chunk 108: Saved 344 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_108.csv
# Chunk 109: processing ...
# Chunk 109: Generated 448 candidate pairs
# Chunk 109: Unique registration_form_id in candidates: 78
# add_features: processing chunk with 448 rows
# Chunk 109: Features computed for 448 candidates
# Chunk 109: Predictions made
# Chunk 109: Saved 448 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_109.csv
# Chunk 110: processing ...
# Chunk 110: Generated 534 candidate pairs
# Chunk 110: Unique registration_form_id in candidates: 75
# add_features: processing chunk with 534 rows
# Chunk 110: Features computed for 534 candidates
# Chunk 110: Predictions made
# Chunk 110: Saved 534 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_110.csv
# Chunk 111: processing ...
# Chunk 111: Generated 274 candidate pairs
# Chunk 111: Unique registration_form_id in candidates: 61
# add_features: processing chunk with 274 rows
# Chunk 111: Features computed for 274 candidates
# Chunk 111: Predictions made
# Chunk 111: Saved 274 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_111.csv
# Chunk 112: processing ...
# Chunk 112: Generated 259 candidate pairs
# Chunk 112: Unique registration_form_id in candidates: 60
# add_features: processing chunk with 259 rows
# Chunk 112: Features computed for 259 candidates
# Chunk 112: Predictions made
# Chunk 112: Saved 259 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_112.csv
# Chunk 113: processing ...
# Chunk 113: Generated 287 candidate pairs
# Chunk 113: Unique registration_form_id in candidates: 66
# add_features: processing chunk with 287 rows
# Chunk 113: Features computed for 287 candidates
# Chunk 113: Predictions made
# Chunk 113: Saved 287 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_113.csv
# Chunk 114: processing ...
# Chunk 114: Generated 255 candidate pairs
# Chunk 114: Unique registration_form_id in candidates: 62
# add_features: processing chunk with 255 rows
# Chunk 114: Features computed for 255 candidates
# Chunk 114: Predictions made
# Chunk 114: Saved 255 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_114.csv
# Chunk 115: processing ...
# Chunk 115: Generated 244 candidate pairs
# Chunk 115: Unique registration_form_id in candidates: 69
# add_features: processing chunk with 244 rows
# Chunk 115: Features computed for 244 candidates
# Chunk 115: Predictions made
# Chunk 115: Saved 244 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_115.csv
# Chunk 116: processing ...
# Chunk 116: Generated 290 candidate pairs
# Chunk 116: Unique registration_form_id in candidates: 68
# add_features: processing chunk with 290 rows
# Chunk 116: Features computed for 290 candidates
# Chunk 116: Predictions made
# Chunk 116: Saved 290 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_116.csv
# Chunk 117: processing ...
# Chunk 117: Generated 203 candidate pairs
# Chunk 117: Unique registration_form_id in candidates: 57
# add_features: processing chunk with 203 rows
# Chunk 117: Features computed for 203 candidates
# Chunk 117: Predictions made
# Chunk 117: Saved 203 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_117.csv
# Chunk 118: processing ...
# Chunk 118: Generated 167 candidate pairs
# Chunk 118: Unique registration_form_id in candidates: 44
# add_features: processing chunk with 167 rows
# Chunk 118: Features computed for 167 candidates
# Chunk 118: Predictions made
# Chunk 118: Saved 167 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_118.csv
# Chunk 119: processing ...
# Chunk 119: Generated 647 candidate pairs
# Chunk 119: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 647 rows
# Chunk 119: Features computed for 647 candidates
# Chunk 119: Predictions made
# Chunk 119: Saved 647 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_119.csv
# Chunk 120: processing ...
# Chunk 120: Generated 727 candidate pairs
# Chunk 120: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 727 rows
# Chunk 120: Features computed for 727 candidates
# Chunk 120: Predictions made
# Chunk 120: Saved 727 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_120.csv
# Chunk 121: processing ...
# Chunk 121: Generated 758 candidate pairs
# Chunk 121: Unique registration_form_id in candidates: 75
# add_features: processing chunk with 758 rows
# Chunk 121: Features computed for 758 candidates
# Chunk 121: Predictions made
# Chunk 121: Saved 758 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_121.csv
# Chunk 122: processing ...
# Chunk 122: Generated 634 candidate pairs
# Chunk 122: Unique registration_form_id in candidates: 72
# add_features: processing chunk with 634 rows
# Chunk 122: Features computed for 634 candidates
# Chunk 122: Predictions made
# Chunk 122: Saved 634 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_122.csv
# Chunk 123: processing ...
# Chunk 123: Generated 473 candidate pairs
# ...
# Chunk 297: processing ...
# Chunk 297: Generated 298 candidate pairs
# Chunk 297: Unique registration_form_id in candidates: 64
# add_features: processing chunk with 298 rows
# Chunk 297: Features computed for 298 candidates
# Chunk 297: Predictions made
# Chunk 297: Saved 298 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_297.csv
# Chunk 298: processing ...
# Chunk 298: Generated 238 candidate pairs
# Chunk 298: Unique registration_form_id in candidates: 67
# add_features: processing chunk with 238 rows
# Chunk 298: Features computed for 238 candidates
# Chunk 298: Predictions made
# Chunk 298: Saved 238 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_298.csv
# Chunk 299: processing ...
# Chunk 299: Generated 236 candidate pairs
# Chunk 299: Unique registration_form_id in candidates: 68
# add_features: processing chunk with 236 rows
# Chunk 299: Features computed for 236 candidates
# Chunk 299: Predictions made
# Chunk 299: Saved 236 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_299.csv
# Chunk 300: processing ...
# Chunk 300: Generated 271 candidate pairs
# Chunk 300: Unique registration_form_id in candidates: 74
# add_features: processing chunk with 271 rows
# Chunk 300: Features computed for 271 candidates
# Chunk 300: Predictions made
# Chunk 300: Saved 271 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_300.csv
# Chunk 301: processing ...
# Chunk 301: Generated 380 candidate pairs
# Chunk 301: Unique registration_form_id in candidates: 70
# add_features: processing chunk with 380 rows
# Chunk 301: Features computed for 380 candidates
# Chunk 301: Predictions made
# Chunk 301: Saved 380 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_301.csv
# Chunk 302: processing ...
# Chunk 302: Generated 365 candidate pairs
# Chunk 302: Unique registration_form_id in candidates: 74
# add_features: processing chunk with 365 rows
# Chunk 302: Features computed for 365 candidates
# Chunk 302: Predictions made
# Chunk 302: Saved 365 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_302.csv
# Chunk 303: processing ...
# Chunk 303: Generated 308 candidate pairs
# Chunk 303: Unique registration_form_id in candidates: 75
# add_features: processing chunk with 308 rows
# Chunk 303: Features computed for 308 candidates
# Chunk 303: Predictions made
# Chunk 303: Saved 308 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_303.csv
# Chunk 304: processing ...
# Chunk 304: Generated 298 candidate pairs
# Chunk 304: Unique registration_form_id in candidates: 66
# add_features: processing chunk with 298 rows
# Chunk 304: Features computed for 298 candidates
# Chunk 304: Predictions made
# Chunk 304: Saved 298 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_304.csv
# Chunk 305: processing ...
# Chunk 305: Generated 292 candidate pairs
# Chunk 305: Unique registration_form_id in candidates: 67
# add_features: processing chunk with 292 rows
# Chunk 305: Features computed for 292 candidates
# Chunk 305: Predictions made
# Chunk 305: Saved 292 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_305.csv
# Chunk 306: processing ...
# Chunk 306: Generated 309 candidate pairs
# Chunk 306: Unique registration_form_id in candidates: 69
# add_features: processing chunk with 309 rows
# Chunk 306: Features computed for 309 candidates
# Chunk 306: Predictions made
# Chunk 306: Saved 309 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_306.csv
# Chunk 307: processing ...
# Chunk 307: Generated 460 candidate pairs
# Chunk 307: Unique registration_form_id in candidates: 80
# add_features: processing chunk with 460 rows
# Chunk 307: Features computed for 460 candidates
# Chunk 307: Predictions made
# Chunk 307: Saved 460 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_307.csv
# Chunk 308: processing ...
# Chunk 308: Generated 441 candidate pairs
# Chunk 308: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 441 rows
# Chunk 308: Features computed for 441 candidates
# Chunk 308: Predictions made
# Chunk 308: Saved 441 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_308.csv
# Chunk 309: processing ...
# Chunk 309: Generated 313 candidate pairs
# Chunk 309: Unique registration_form_id in candidates: 72
# add_features: processing chunk with 313 rows
# Chunk 309: Features computed for 313 candidates
# Chunk 309: Predictions made
# Chunk 309: Saved 313 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_309.csv
# Chunk 310: processing ...
# Chunk 310: Generated 316 candidate pairs
# Chunk 310: Unique registration_form_id in candidates: 64
# add_features: processing chunk with 316 rows
# Chunk 310: Features computed for 316 candidates
# Chunk 310: Predictions made
# Chunk 310: Saved 316 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_310.csv
# Chunk 311: processing ...
# Chunk 311: Generated 263 candidate pairs
# Chunk 311: Unique registration_form_id in candidates: 64
# add_features: processing chunk with 263 rows
# Chunk 311: Features computed for 263 candidates
# Chunk 311: Predictions made
# Chunk 311: Saved 263 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_311.csv
# Chunk 312: processing ...
# Chunk 312: Generated 343 candidate pairs
# Chunk 312: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 343 rows
# Chunk 312: Features computed for 343 candidates
# Chunk 312: Predictions made
# Chunk 312: Saved 343 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_312.csv
# Chunk 313: processing ...
# Chunk 313: Generated 327 candidate pairs
# Chunk 313: Unique registration_form_id in candidates: 78
# add_features: processing chunk with 327 rows
# Chunk 313: Features computed for 327 candidates
# Chunk 313: Predictions made
# Chunk 313: Saved 327 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_313.csv
# Chunk 314: processing ...
# Chunk 314: Generated 266 candidate pairs
# Chunk 314: Unique registration_form_id in candidates: 70
# add_features: processing chunk with 266 rows
# Chunk 314: Features computed for 266 candidates
# Chunk 314: Predictions made
# Chunk 314: Saved 266 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_314.csv
# Chunk 315: processing ...
# Chunk 315: Generated 282 candidate pairs
# Chunk 315: Unique registration_form_id in candidates: 75
# add_features: processing chunk with 282 rows
# Chunk 315: Features computed for 282 candidates
# Chunk 315: Predictions made
# Chunk 315: Saved 282 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_315.csv
# Chunk 316: processing ...
# Chunk 316: Generated 255 candidate pairs
# Chunk 316: Unique registration_form_id in candidates: 71
# add_features: processing chunk with 255 rows
# Chunk 316: Features computed for 255 candidates
# Chunk 316: Predictions made
# Chunk 316: Saved 255 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_316.csv
# Chunk 317: processing ...
# Chunk 317: Generated 294 candidate pairs
# Chunk 317: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 294 rows
# Chunk 317: Features computed for 294 candidates
# Chunk 317: Predictions made
# Chunk 317: Saved 294 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_317.csv
# Chunk 318: processing ...
# Chunk 318: Generated 295 candidate pairs
# Chunk 318: Unique registration_form_id in candidates: 72
# add_features: processing chunk with 295 rows
# Chunk 318: Features computed for 295 candidates
# Chunk 318: Predictions made
# Chunk 318: Saved 295 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_318.csv
# Chunk 319: processing ...
# Chunk 319: Generated 289 candidate pairs
# Chunk 319: Unique registration_form_id in candidates: 74
# add_features: processing chunk with 289 rows
# Chunk 319: Features computed for 289 candidates
# Chunk 319: Predictions made
# Chunk 319: Saved 289 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_319.csv
# Chunk 320: processing ...
# Chunk 320: Generated 289 candidate pairs
# Chunk 320: Unique registration_form_id in candidates: 74
# add_features: processing chunk with 289 rows
# Chunk 320: Features computed for 289 candidates
# Chunk 320: Predictions made
# Chunk 320: Saved 289 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_320.csv
# Chunk 321: processing ...
# Chunk 321: Generated 290 candidate pairs
# Chunk 321: Unique registration_form_id in candidates: 72
# add_features: processing chunk with 290 rows
# Chunk 321: Features computed for 290 candidates
# Chunk 321: Predictions made
# Chunk 321: Saved 290 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_321.csv
# Chunk 322: processing ...
# Chunk 322: Generated 306 candidate pairs
# Chunk 322: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 306 rows
# Chunk 322: Features computed for 306 candidates
# Chunk 322: Predictions made
# Chunk 322: Saved 306 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_322.csv
# Chunk 323: processing ...
# Chunk 323: Generated 310 candidate pairs
# Chunk 323: Unique registration_form_id in candidates: 77
# add_features: processing chunk with 310 rows
# Chunk 323: Features computed for 310 candidates
# Chunk 323: Predictions made
# Chunk 323: Saved 310 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_323.csv
# Chunk 324: processing ...
# Chunk 324: Generated 248 candidate pairs
# Chunk 324: Unique registration_form_id in candidates: 73
# add_features: processing chunk with 248 rows
# Chunk 324: Features computed for 248 candidates
# Chunk 324: Predictions made
# Chunk 324: Saved 248 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_324.csv
# Chunk 325: processing ...
# Chunk 325: Generated 251 candidate pairs
# Chunk 325: Unique registration_form_id in candidates: 69
# add_features: processing chunk with 251 rows
# Chunk 325: Features computed for 251 candidates
# Chunk 325: Predictions made
# Chunk 325: Saved 251 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_325.csv
# Chunk 326: processing ...
# Chunk 326: Generated 297 candidate pairs
# Chunk 326: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 297 rows
# Chunk 326: Features computed for 297 candidates
# Chunk 326: Predictions made
# Chunk 326: Saved 297 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_326.csv
# Chunk 327: processing ...
# Chunk 327: Generated 297 candidate pairs
# Chunk 327: Unique registration_form_id in candidates: 75
# add_features: processing chunk with 297 rows
# Chunk 327: Features computed for 297 candidates
# Chunk 327: Predictions made
# Chunk 327: Saved 297 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_327.csv
# Chunk 328: processing ...
# Chunk 328: Generated 369 candidate pairs
# Chunk 328: Unique registration_form_id in candidates: 77
# add_features: processing chunk with 369 rows
# Chunk 328: Features computed for 369 candidates
# Chunk 328: Predictions made
# Chunk 328: Saved 369 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_328.csv
# Chunk 329: processing ...
# Chunk 329: Generated 319 candidate pairs
# Chunk 329: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 319 rows
# Chunk 329: Features computed for 319 candidates
# Chunk 329: Predictions made
# Chunk 329: Saved 319 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_329.csv
# Chunk 330: processing ...
# Chunk 330: Generated 294 candidate pairs
# Chunk 330: Unique registration_form_id in candidates: 75
# add_features: processing chunk with 294 rows
# Chunk 330: Features computed for 294 candidates
# Chunk 330: Predictions made
# Chunk 330: Saved 294 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_330.csv
# Chunk 331: processing ...
# Chunk 331: Generated 307 candidate pairs
# Chunk 331: Unique registration_form_id in candidates: 71
# add_features: processing chunk with 307 rows
# Chunk 331: Features computed for 307 candidates
# Chunk 331: Predictions made
# Chunk 331: Saved 307 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_331.csv
# Chunk 332: processing ...
# Chunk 332: Generated 281 candidate pairs
# Chunk 332: Unique registration_form_id in candidates: 74
# add_features: processing chunk with 281 rows
# Chunk 332: Features computed for 281 candidates
# Chunk 332: Predictions made
# Chunk 332: Saved 281 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_332.csv
# Chunk 333: processing ...
# Chunk 333: Generated 331 candidate pairs
# Chunk 333: Unique registration_form_id in candidates: 71
# add_features: processing chunk with 331 rows
# Chunk 333: Features computed for 331 candidates
# Chunk 333: Predictions made
# Chunk 333: Saved 331 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_333.csv
# Chunk 334: processing ...
# Chunk 334: Generated 340 candidate pairs
# Chunk 334: Unique registration_form_id in candidates: 76
# add_features: processing chunk with 340 rows
# Chunk 334: Features computed for 340 candidates
# Chunk 334: Predictions made
# Chunk 334: Saved 340 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_334.csv
# Chunk 335: processing ...
# Chunk 335: Generated 328 candidate pairs
# Chunk 335: Unique registration_form_id in candidates: 74
# add_features: processing chunk with 328 rows
# Chunk 335: Features computed for 328 candidates
# Chunk 335: Predictions made
# Chunk 335: Saved 328 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_335.csv
# Chunk 336: processing ...
# Chunk 336: Generated 282 candidate pairs
# Chunk 336: Unique registration_form_id in candidates: 73
# add_features: processing chunk with 282 rows
# Chunk 336: Features computed for 282 candidates
# Chunk 336: Predictions made
# Chunk 336: Saved 282 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_336.csv
# Chunk 337: processing ...
# Chunk 337: Generated 316 candidate pairs
# Chunk 337: Unique registration_form_id in candidates: 77
# add_features: processing chunk with 316 rows
# Chunk 337: Features computed for 316 candidates
# Chunk 337: Predictions made
# Chunk 337: Saved 316 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_337.csv
# Chunk 338: processing ...
# Chunk 338: Generated 6 candidate pairs
# Chunk 338: Unique registration_form_id in candidates: 6
# add_features: processing chunk with 6 rows
# Chunk 338: Features computed for 6 candidates
# Chunk 338: Predictions made
# Chunk 338: Saved 6 rows to /Users/borismartinez/Documents/GitHub/engage/chunk_folder/chunk_prototype/predicted_matches_chunk_338.csv
# Processing complete. Total chunks processed: 339
