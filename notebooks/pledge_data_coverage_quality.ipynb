# %%
import pandas as pd
import inflection
import re



# Update with your actual CSV path
pledge_data_path = "/Users/borismartinez/Documents/GitHub/engage/data/pledge_data.csv"

# Load the pledge data
pledge_df = pd.read_csv(pledge_data_path, low_memory=False)
print(f"Total pledge records loaded: {len(pledge_df)}")

# 1. Rename columns: lower case and underscores, no spaces
pledge_df.columns = [inflection.underscore(col.strip()) for col in pledge_df.columns]
pledge_df.columns = [("name" if col.startswith("name (first last or common name)") else col) for col in pledge_df.columns]

# Additional renaming fixes:
new_columns = []
for col in pledge_df.columns:
    # Remove any trailing _(engage_miami) pattern
    col = re.sub(r'_\((engage_miami)\)$', '', col)
    # Rename 'date_created' (assuming lowercase now)
    if col == 'date created':
        col = 'date_created'  # already good if this is correct, else modify as needed
    # Normalize zip/postal variations to 'zip'
    elif col in ['zip/postal']:
        col = 'zip'
    # Normalize state/province variations to 'state'
    elif col in ['state/province']:
        col = 'state'
    new_columns.append(col)

pledge_df.columns = new_columns

# 1.1 Add Year, Month Column based on date_contacted
if 'date_contacted' in pledge_df.columns:
    pledge_df['date_contacted'] = pd.to_datetime(pledge_df['date_contacted'], errors='coerce')
    pledge_df['year'] = pledge_df['date_contacted'].dt.year
    pledge_df['month'] = pledge_df['date_contacted'].dt.month
else:
    print("Warning: 'date_contacted' column not found in the pledge data.")



# 2. Convert all string columns to lower case (skip numeric columns)
for col in pledge_df.columns:
    if pd.api.types.is_string_dtype(pledge_df[col]):
        pledge_df[col] = pledge_df[col].astype(str).str.lower().str.strip()

# 3. Count total rows and count of distinct rows by all columns combined
total_rows = len(pledge_df)
distinct_rows = pledge_df.drop_duplicates().shape[0]

print(f"Total pledge records: {total_rows}")
print(f"Distinct pledge records (all columns): {distinct_rows}")


# Show first few rows for preliminary understanding
pledge_df.head()


# 4. Usable & missing values count and percent per key column(s)
# Define key columns to assess usability (example names, adjust as needed)
key_cols = ['name', 'city', 'county', 'address' ]

# Define strings that count as missing
null_equivs = ['', 'na', 'nan', 'null', 'none', 'undefined']

def is_missing_strict(series):
    # True if value is NaN or one of null-equivalent strings (case-insensitive)
    return series.isna() | series.astype(str).str.strip().str.lower().isin(null_equivs)


# Calculate missing counts and percentages per key col
missing_counts = {}
for col in key_cols:
    missing_counts[col] = is_missing_strict(pledge_df[col]).sum()

missing_df = pd.DataFrame.from_dict(missing_counts, orient='index', columns=['missing_count'])
missing_df['missing_pct'] = (missing_df['missing_count'] / total_rows) * 100

# Compute usable mask per row (all key cols non-missing)
usable_mask = ~pd.concat([is_missing_strict(pledge_df[col]) for col in key_cols], axis=1).any(axis=1)

# Add usable column to dataframe
pledge_df['usable'] = usable_mask

print("\nMissing counts and percentages per key column:")
print(missing_df)

print(f"\nTotal usable records based on keys {key_cols}: {pledge_df['usable'].sum()} ({pledge_df['usable'].mean()*100:.2f}%)")
# Out:
# Total pledge records loaded: 10698
# Total pledge records: 10698
# Distinct pledge records (all columns): 10698
#
# Missing counts and percentages per key column:
#          missing_count  missing_pct
# name                 0         0.00
# city               943         8.81
# county            1005         9.39
# address           5863        54.80
#
# Total usable records based on keys ['name', 'city', 'county', 'address']: 4803 (44.90%)

# %%
import pandas as pd

# Assuming pledge_df loaded and columns renamed earlier

# Select issue columns based on position
issue_cols = pledge_df.columns[15:31]  # inclusive column 14 to 32 (zero-indexed)

# Clean and create binary flags for 'x' (case-insensitive)
for col in issue_cols:
    # Convert to string, lower case and strip
    pledge_df[col] = pledge_df[col].astype(str).str.lower().str.strip()
    # Create binary column: 1 if 'x', else 0
    pledge_df[col + '_flag'] = (pledge_df[col] == 'x').astype(int)

# Summarize total and percentage for each issue flag
summary_list = []
total_pledges = len(pledge_df)

for col in issue_cols:
    flag_col = col + '_flag'
    total_marked = pledge_df[flag_col].sum()
    pct_marked = total_marked / total_pledges * 100
    summary_list.append({'issue': col, 'total_marked': total_marked, 'pct_marked': pct_marked})

issues_summary_df = pd.DataFrame(summary_list).sort_values(by='pct_marked', ascending=False)

print("Issue coverage summary:")
print(issues_summary_df)
# Out:
# Issue coverage summary:
#                     issue  total_marked  pct_marked
# 7   housing_affordability          4619       43.18
# 1   affordable_healthcare          4100       38.32
# 0         abortion_access          4065       38.00
# 6    gun_violence_prevent          3987       37.27
# 5      education_(public)          3915       36.60
# 11          racial_equity          3122       29.18
# 14       updates_interest          3121       29.17
# 4       economic_mobility          2580       24.12
# 2         climate_and_env          2373       22.18
# 15     volunteer_interest          2292       21.42
# 8         lgbtqia+_rights          2288       21.39
# 10         public_transit          2287       21.38
# 12          voting_rights          1900       17.76
# 9    pro_immigrant_policy          1630       15.24
# 3        decrim_marijuana          1537       14.37
# 13        member_interest           532        4.97

# %%
# Sort by total_marked descending and add rank starting at 1
issues_summary_df = issues_summary_df.sort_values(by='total_marked', ascending=False)
issues_summary_df['rank'] = range(1, len(issues_summary_df) + 1)

# Optionally reorder columns for readability
issues_summary_df = issues_summary_df[['rank', 'issue', 'total_marked', 'pct_marked']]

print("Ranked Issue Coverage Summary:")
print(issues_summary_df)
# Out:
# Ranked Issue Coverage Summary:
#     rank                  issue  total_marked  pct_marked
# 7      1  housing_affordability          4619       43.18
# 1      2  affordable_healthcare          4100       38.32
# 0      3        abortion_access          4065       38.00
# 6      4   gun_violence_prevent          3987       37.27
# 5      5     education_(public)          3915       36.60
# 11     6          racial_equity          3122       29.18
# 14     7       updates_interest          3121       29.17
# 4      8      economic_mobility          2580       24.12
# 2      9        climate_and_env          2373       22.18
# 15    10     volunteer_interest          2292       21.42
# 8     11        lgbtqia+_rights          2288       21.39
# 10    12         public_transit          2287       21.38
# 12    13          voting_rights          1900       17.76
# 9     14   pro_immigrant_policy          1630       15.24
# 3     15       decrim_marijuana          1537       14.37
# 13    16        member_interest           532        4.97

# %%
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format

def compute_conditional_cooccurrence(co_occurrence, filter_desc="overall"):
    """
    Takes a co-occurrence DataFrame, computes the conditional co-occurrence by normalizing rows,
    formats numbers to 2 decimals (including trailing zeros), and prints the result.
    
    Args:
        co_occurrence (pd.DataFrame): Square co-occurrence counts matrix.
        filter_desc (str): Description to print about the filtering for context.
    
    Returns:
        pd.DataFrame: Formatted conditional co-occurrence matrix as strings.
    """
    # Get diagonal as a NumPy array (counts of each issue alone)
    diag = np.diag(co_occurrence.values)
    
    # Replace zeros on diagonal with 1 to avoid division by zero errors
    diag_safe = np.where(diag == 0, 1, diag)
    
    # Normalize rows by diagonal
    conditional_cooccurrence = co_occurrence.div(diag_safe, axis=0)
    
    # Format with 2 decimals including trailing zeros
    conditional_cooccurrence_str = conditional_cooccurrence.applymap(lambda x: f"{x:.2f}")
    
    print(f"\nConditional co-occurrence matrix ({filter_desc}):")
    print(conditional_cooccurrence)
    
    return conditional_cooccurrence_str


def compute_yearly_cooccurrence(df, year_column, year, issue_cols):
    """
    Filters the DataFrame by contact_year, computes co-occurrence matrix on flagged issues,
    then returns the formatted conditional co-occurrence matrix.

    Args:
        df (pd.DataFrame): Full dataframe including flag columns and year column.
        year_column (str): Column to filter years on e.g., 'contact_year'.
        year (int): The year value to filter on.
        issue_cols (list): List of binary flag columns.

    Returns:
        pd.DataFrame: Conditional co-occurrence matrix formatted as strings.
    """
    df_filtered = df[df[year_column] == year]

    # Select issue flag columns only
    df_issues = df_filtered[issue_cols]

    co_occurrence = df_issues.T.dot(df_issues)
    return compute_conditional_cooccurrence(co_occurrence, filter_desc=f"year {year}")

# %%
issue_flag_cols = [col for col in pledge_df.columns if col.endswith('_flag')]

# Compute for 2023 using the 'contact_year' column
formatted_2023 = compute_yearly_cooccurrence(
    pledge_df,
    year_column='year',
    year=2023,
    issue_cols=issue_flag_cols
)
# Out:
# Conditional co-occurrence matrix (year 2023):
#                             abortion_access_flag  affordable_healthcare_flag  \
# abortion_access_flag                        1.00                        0.47
# affordable_healthcare_flag                  0.44                        1.00
# climate_and_env_flag                        0.51                        0.52
# decrim_marijuana_flag                       0.51                        0.48
# economic_mobility_flag                      0.41                        0.51
# education_(public)_flag                     0.39                        0.46
# gun_violence_prevent_flag                   0.47                        0.43
# housing_affordability_flag                  0.38                        0.51
# lgbtqia+_rights_flag                        0.65                        0.45
# pro_immigrant_policy_flag                   0.50                        0.51
# public_transit_flag                         0.42                        0.48
# racial_equity_flag                          0.49                        0.47
# voting_rights_flag                          0.48                        0.48
# member_interest_flag                        0.43                        0.46
# updates_interest_flag                       0.40                        0.40
# volunteer_interest_flag                     0.47                        0.45
#
#                             climate_and_env_flag  decrim_marijuana_flag  \
# abortion_access_flag                        0.33                   0.25
# affordable_healthcare_flag                  0.32                   0.22
# climate_and_env_flag                        1.00                   0.31
# decrim_marijuana_flag                       0.41                   1.00
# economic_mobility_flag                      0.40                   0.31
# education_(public)_flag                     0.32                   0.21
# gun_violence_prevent_flag                   0.35                   0.25
# housing_affordability_flag                  0.30                   0.24
# lgbtqia+_rights_flag                        0.37                   0.28
# pro_immigrant_policy_flag                   0.42                   0.32
# public_transit_flag                         0.41                   0.31
# racial_equity_flag                          0.31                   0.23
# voting_rights_flag                          0.37                   0.28
# member_interest_flag                        0.35                   0.26
# updates_interest_flag                       0.28                   0.20
# volunteer_interest_flag                     0.29                   0.20
#
#                             economic_mobility_flag  education_(public)_flag  \
# abortion_access_flag                          0.20                     0.40
# affordable_healthcare_flag                    0.24                     0.44
# climate_and_env_flag                          0.30                     0.49
# decrim_marijuana_flag                         0.31                     0.44
# economic_mobility_flag                        1.00                     0.55
# education_(public)_flag                       0.27                     1.00
# gun_violence_prevent_flag                     0.23                     0.43
# housing_affordability_flag                    0.27                     0.46
# lgbtqia+_rights_flag                          0.23                     0.43
# pro_immigrant_policy_flag                     0.28                     0.48
# public_transit_flag                           0.37                     0.53
# racial_equity_flag                            0.21                     0.44
# voting_rights_flag                            0.30                     0.56
# member_interest_flag                          0.25                     0.45
# updates_interest_flag                         0.21                     0.43
# volunteer_interest_flag                       0.20                     0.43
#
#                             gun_violence_prevent_flag  \
# abortion_access_flag                             0.48
# affordable_healthcare_flag                       0.43
# climate_and_env_flag                             0.55
# decrim_marijuana_flag                            0.54
# economic_mobility_flag                           0.49
# education_(public)_flag                          0.44
# gun_violence_prevent_flag                        1.00
# housing_affordability_flag                       0.42
# lgbtqia+_rights_flag                             0.50
# pro_immigrant_policy_flag                        0.54
# public_transit_flag                              0.49
# racial_equity_flag                               0.49
# voting_rights_flag                               0.48
# member_interest_flag                             0.44
# updates_interest_flag                            0.44
# volunteer_interest_flag                          0.43
#
#                             housing_affordability_flag  lgbtqia+_rights_flag  \
# abortion_access_flag                              0.42                  0.44
# affordable_healthcare_flag                        0.53                  0.29
# climate_and_env_flag                              0.50                  0.39
# decrim_marijuana_flag                             0.53                  0.39
# economic_mobility_flag                            0.61                  0.32
# education_(public)_flag                           0.50                  0.29
# gun_violence_prevent_flag                         0.45                  0.33
# housing_affordability_flag                        1.00                  0.26
# lgbtqia+_rights_flag                              0.42                  1.00
# pro_immigrant_policy_flag                         0.52                  0.37
# public_transit_flag                               0.59                  0.35
# racial_equity_flag                                0.43                  0.36
# voting_rights_flag                                0.48                  0.39
# member_interest_flag                              0.51                  0.35
# updates_interest_flag                             0.45                  0.27
# volunteer_interest_flag                           0.42                  0.32
#
#                             pro_immigrant_policy_flag  public_transit_flag  \
# abortion_access_flag                             0.26                 0.24
# affordable_healthcare_flag                       0.25                 0.26
# climate_and_env_flag                             0.33                 0.35
# decrim_marijuana_flag                            0.33                 0.35
# economic_mobility_flag                           0.29                 0.42
# education_(public)_flag                          0.25                 0.30
# gun_violence_prevent_flag                        0.27                 0.26
# housing_affordability_flag                       0.24                 0.30
# lgbtqia+_rights_flag                             0.28                 0.29
# pro_immigrant_policy_flag                        1.00                 0.33
# public_transit_flag                              0.31                 1.00
# racial_equity_flag                               0.26                 0.25
# voting_rights_flag                               0.31                 0.34
# member_interest_flag                             0.23                 0.27
# updates_interest_flag                            0.22                 0.26
# volunteer_interest_flag                          0.21                 0.23
#
#                             racial_equity_flag  voting_rights_flag  \
# abortion_access_flag                      0.48                0.30
# affordable_healthcare_flag                0.44                0.29
# climate_and_env_flag                      0.47                0.36
# decrim_marijuana_flag                     0.47                0.36
# economic_mobility_flag                    0.43                0.38
# education_(public)_flag                   0.43                0.35
# gun_violence_prevent_flag                 0.47                0.29
# housing_affordability_flag                0.39                0.28
# lgbtqia+_rights_flag                      0.53                0.36
# pro_immigrant_policy_flag                 0.49                0.38
# public_transit_flag                       0.44                0.38
# racial_equity_flag                        1.00                0.34
# voting_rights_flag                        0.54                1.00
# member_interest_flag                      0.47                0.34
# updates_interest_flag                     0.42                0.26
# volunteer_interest_flag                   0.44                0.25
#
#                             member_interest_flag  updates_interest_flag  \
# abortion_access_flag                        0.09                   0.44
# affordable_healthcare_flag                  0.09                   0.42
# climate_and_env_flag                        0.11                   0.46
# decrim_marijuana_flag                       0.11                   0.45
# economic_mobility_flag                      0.10                   0.48
# education_(public)_flag                     0.09                   0.46
# gun_violence_prevent_flag                   0.09                   0.46
# housing_affordability_flag                  0.10                   0.45
# lgbtqia+_rights_flag                        0.11                   0.43
# pro_immigrant_policy_flag                   0.09                   0.46
# public_transit_flag                         0.10                   0.50
# racial_equity_flag                          0.10                   0.46
# voting_rights_flag                          0.11                   0.44
# member_interest_flag                        1.00                   0.51
# updates_interest_flag                       0.10                   1.00
# volunteer_interest_flag                     0.22                   0.29
#
#                             volunteer_interest_flag
# abortion_access_flag                           0.28
# affordable_healthcare_flag                     0.25
# climate_and_env_flag                           0.26
# decrim_marijuana_flag                          0.24
# economic_mobility_flag                         0.24
# education_(public)_flag                        0.25
# gun_violence_prevent_flag                      0.25
# housing_affordability_flag                     0.23
# lgbtqia+_rights_flag                           0.27
# pro_immigrant_policy_flag                      0.24
# public_transit_flag                            0.24
# racial_equity_flag                             0.26
# voting_rights_flag                             0.24
# member_interest_flag                           0.62
# updates_interest_flag                          0.16
# volunteer_interest_flag                        1.00
# /var/folders/h3/qc0834sx6gjb7174_439hbkc0000gn/T/ipykernel_38108/381646917.py:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   conditional_cooccurrence_str = conditional_cooccurrence.applymap(lambda x: f"{x:.2f}")

# %%
city_year_filtered = pledge_df[(pledge_df['city'] == 'Miami') & (pledge_df['year'] == 2023)]
miami_ls = compute_yearly_cooccurrence(
    city_year_filtered,
    year_column='year',
    year=2023,
    issue_cols=issue_flag_cols
)
# Out:
# Conditional co-occurrence matrix (year 2023):
#                             abortion_access_flag  affordable_healthcare_flag  \
# abortion_access_flag                        1.00                        0.44
# affordable_healthcare_flag                  0.43                        1.00
# climate_and_env_flag                        0.44                        0.52
# decrim_marijuana_flag                       0.51                        0.48
# economic_mobility_flag                      0.38                        0.51
# education_(public)_flag                     0.38                        0.45
# gun_violence_prevent_flag                   0.43                        0.41
# housing_affordability_flag                  0.35                        0.48
# lgbtqia+_rights_flag                        0.68                        0.44
# pro_immigrant_policy_flag                   0.48                        0.49
# public_transit_flag                         0.39                        0.52
# racial_equity_flag                          0.46                        0.45
# voting_rights_flag                          0.49                        0.47
# member_interest_flag                        0.47                        0.52
# updates_interest_flag                       0.38                        0.42
# volunteer_interest_flag                     0.45                        0.43
#
#                             climate_and_env_flag  decrim_marijuana_flag  \
# abortion_access_flag                        0.33                   0.23
# affordable_healthcare_flag                  0.38                   0.22
# climate_and_env_flag                        1.00                   0.29
# decrim_marijuana_flag                       0.46                   1.00
# economic_mobility_flag                      0.44                   0.30
# education_(public)_flag                     0.34                   0.20
# gun_violence_prevent_flag                   0.36                   0.24
# housing_affordability_flag                  0.30                   0.22
# lgbtqia+_rights_flag                        0.40                   0.28
# pro_immigrant_policy_flag                   0.42                   0.27
# public_transit_flag                         0.41                   0.30
# racial_equity_flag                          0.31                   0.23
# voting_rights_flag                          0.41                   0.29
# member_interest_flag                        0.42                   0.20
# updates_interest_flag                       0.30                   0.21
# volunteer_interest_flag                     0.35                   0.17
#
#                             economic_mobility_flag  education_(public)_flag  \
# abortion_access_flag                          0.19                     0.39
# affordable_healthcare_flag                    0.25                     0.45
# climate_and_env_flag                          0.30                     0.47
# decrim_marijuana_flag                         0.33                     0.45
# economic_mobility_flag                        1.00                     0.59
# education_(public)_flag                       0.29                     1.00
# gun_violence_prevent_flag                     0.24                     0.42
# housing_affordability_flag                    0.27                     0.46
# lgbtqia+_rights_flag                          0.22                     0.40
# pro_immigrant_policy_flag                     0.30                     0.50
# public_transit_flag                           0.37                     0.52
# racial_equity_flag                            0.23                     0.43
# voting_rights_flag                            0.29                     0.58
# member_interest_flag                          0.23                     0.44
# updates_interest_flag                         0.22                     0.40
# volunteer_interest_flag                       0.20                     0.41
#
#                             gun_violence_prevent_flag  \
# abortion_access_flag                             0.50
# affordable_healthcare_flag                       0.47
# climate_and_env_flag                             0.56
# decrim_marijuana_flag                            0.62
# economic_mobility_flag                           0.54
# education_(public)_flag                          0.48
# gun_violence_prevent_flag                        1.00
# housing_affordability_flag                       0.44
# lgbtqia+_rights_flag                             0.53
# pro_immigrant_policy_flag                        0.57
# public_transit_flag                              0.54
# racial_equity_flag                               0.52
# voting_rights_flag                               0.53
# member_interest_flag                             0.47
# updates_interest_flag                            0.47
# volunteer_interest_flag                          0.49
#
#                             housing_affordability_flag  lgbtqia+_rights_flag  \
# abortion_access_flag                              0.41                  0.44
# affordable_healthcare_flag                        0.54                  0.28
# climate_and_env_flag                              0.47                  0.35
# decrim_marijuana_flag                             0.54                  0.40
# economic_mobility_flag                            0.61                  0.29
# education_(public)_flag                           0.52                  0.26
# gun_violence_prevent_flag                         0.44                  0.30
# housing_affordability_flag                        1.00                  0.22
# lgbtqia+_rights_flag                              0.39                  1.00
# pro_immigrant_policy_flag                         0.53                  0.32
# public_transit_flag                               0.60                  0.33
# racial_equity_flag                                0.44                  0.34
# voting_rights_flag                                0.51                  0.40
# member_interest_flag                              0.58                  0.34
# updates_interest_flag                             0.47                  0.26
# volunteer_interest_flag                           0.42                  0.36
#
#                             pro_immigrant_policy_flag  public_transit_flag  \
# abortion_access_flag                             0.27                 0.24
# affordable_healthcare_flag                       0.27                 0.32
# climate_and_env_flag                             0.32                 0.35
# decrim_marijuana_flag                            0.34                 0.41
# economic_mobility_flag                           0.33                 0.46
# education_(public)_flag                          0.28                 0.32
# gun_violence_prevent_flag                        0.28                 0.29
# housing_affordability_flag                       0.26                 0.33
# lgbtqia+_rights_flag                             0.28                 0.32
# pro_immigrant_policy_flag                        1.00                 0.34
# public_transit_flag                              0.31                 1.00
# racial_equity_flag                               0.28                 0.28
# voting_rights_flag                               0.34                 0.36
# member_interest_flag                             0.32                 0.32
# updates_interest_flag                            0.25                 0.28
# volunteer_interest_flag                          0.25                 0.29
#
#                             racial_equity_flag  voting_rights_flag  \
# abortion_access_flag                      0.47                0.30
# affordable_healthcare_flag                0.45                0.28
# climate_and_env_flag                      0.43                0.33
# decrim_marijuana_flag                     0.51                0.38
# economic_mobility_flag                    0.47                0.35
# education_(public)_flag                   0.43                0.34
# gun_violence_prevent_flag                 0.46                0.28
# housing_affordability_flag                0.39                0.27
# lgbtqia+_rights_flag                      0.54                0.37
# pro_immigrant_policy_flag                 0.52                0.36
# public_transit_flag                       0.45                0.35
# racial_equity_flag                        1.00                0.33
# voting_rights_flag                        0.56                1.00
# member_interest_flag                      0.49                0.38
# updates_interest_flag                     0.44                0.24
# volunteer_interest_flag                   0.44                0.29
#
#                             member_interest_flag  updates_interest_flag  \
# abortion_access_flag                        0.10                   0.44
# affordable_healthcare_flag                  0.11                   0.48
# climate_and_env_flag                        0.12                   0.48
# decrim_marijuana_flag                       0.10                   0.54
# economic_mobility_flag                      0.10                   0.50
# education_(public)_flag                     0.10                   0.46
# gun_violence_prevent_flag                   0.09                   0.47
# housing_affordability_flag                  0.11                   0.48
# lgbtqia+_rights_flag                        0.12                   0.46
# pro_immigrant_policy_flag                   0.12                   0.51
# public_transit_flag                         0.11                   0.52
# racial_equity_flag                          0.11                   0.50
# voting_rights_flag                          0.14                   0.47
# member_interest_flag                        1.00                   0.52
# updates_interest_flag                       0.10                   1.00
# volunteer_interest_flag                     0.23                   0.33
#
#                             volunteer_interest_flag
# abortion_access_flag                           0.26
# affordable_healthcare_flag                     0.25
# climate_and_env_flag                           0.27
# decrim_marijuana_flag                          0.22
# economic_mobility_flag                         0.23
# education_(public)_flag                        0.23
# gun_violence_prevent_flag                      0.24
# housing_affordability_flag                     0.21
# lgbtqia+_rights_flag                           0.32
# pro_immigrant_policy_flag                      0.26
# public_transit_flag                            0.27
# racial_equity_flag                             0.25
# voting_rights_flag                             0.28
# member_interest_flag                           0.61
# updates_interest_flag                          0.16
# volunteer_interest_flag                        1.00
# /var/folders/h3/qc0834sx6gjb7174_439hbkc0000gn/T/ipykernel_38108/381646917.py:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   conditional_cooccurrence_str = conditional_cooccurrence.applymap(lambda x: f"{x:.2f}")
